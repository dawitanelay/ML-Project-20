# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#keras
from keras.models import Sequential
from keras.optimizers import SGD
from keras.layers import Dense, Input, Dropout
from keras.utils import to_categorical
from keras import initializers
# for combining all the hyper-parameters
import itertools

# %%
#Extracting the training and test sets
train_df = pd.read_csv('../data/monks-1-train.csv').to_numpy()
test_df = pd.read_csv('../data/monks-1-test.csv').to_numpy()

#Preparing train_df for training
train_dataset = train_df[:, 1:7]
train_labelset = train_df[:, 0]
#Preparing test_df for testing
test_dataset = test_df[:, 1:7]
test_labelset = test_df[:, 0]

# %%
# one hot encoding 
def fix_zero(dataset):
  return dataset - 1

def to_one_hot_encoding(dataset):
    fixed_dataset = fix_zero(dataset)
    one_hot_dataset = []
    for column in fixed_dataset.T:
        one_hot_column = to_categorical(column)
        for column_index in range(one_hot_column.shape[1]):
            one_hot_dataset.append(one_hot_column[:,column_index])
    return np.asarray(one_hot_dataset).T

one_hot_train = to_one_hot_encoding(train_dataset)
one_hot_test  = to_one_hot_encoding(test_dataset)
# one_hot_train.shape , train_labelset.shape
# one_hot_test.shape , test_labelset.shape

# %%
# define the grid search parameters after performing screening path
space = {}
space['lr'] = [0.5,0.45,0.55]
space['momentum'] = [0.6,0.7,0.8]
space['num_hidden_units_1'] = [5,6,7]
space['activation_hidden_1'] = ['relu','softmax','tanh','sigmoid']
space['epochs'] = [50 ,90,100,150]

# %%
# All combination of the hyper-paramers
gridParameters=[space['lr'],space['epochs'],space['momentum'],space['num_hidden_units_1'],space['activation_hidden_1']]
allcombination = list(itertools.product(*gridParameters))

# %% [markdown]
# Best: 1.000000 using {'activation_hidden_1': 'softmax', 'epochs': 90, 'lr': 0.5, 'momentum': 0.7, 'num_hidden_units_1': 6}

# %%
model = Sequential()
initializer = initializers.GlorotNormal(seed=52) # seed to produce the same random sample.
model.add(Dense(units=6, kernel_initializer=initializer, input_dim=17, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
sgd = SGD(lr= 0.5, momentum=0.7, nesterov=True)
model.compile(optimizer=sgd, loss='mean_squared_error',metrics=['accuracy'])
history = model.fit(one_hot_train, train_labelset,validation_data=(one_hot_test, test_labelset), epochs= 90, batch_size=10, verbose=1)
# Out:
# Epoch 1/90
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2445 - accuracy: 0.5610 - val_loss: 0.3076 - val_accuracy: 0.5081
# Epoch 2/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2166 - accuracy: 0.7073 - val_loss: 0.2322 - val_accuracy: 0.5754
# Epoch 3/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1689 - accuracy: 0.7724 - val_loss: 0.1986 - val_accuracy: 0.7401
# Epoch 4/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1532 - accuracy: 0.7967 - val_loss: 0.1900 - val_accuracy: 0.7448
# Epoch 5/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1311 - accuracy: 0.8374 - val_loss: 0.1719 - val_accuracy: 0.7796
# Epoch 6/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.
90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0574 - accuracy: 0.9431 - val_loss: 0.0843 - val_accuracy: 0.9165
# Epoch 35/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0573 - accuracy: 0.9431 - val_loss: 0.0842 - val_accuracy: 0.9165
# Epoch 36/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9431 - val_loss: 0.0842 - val_accuracy: 0.9165
# Epoch 37/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9431 - val_loss: 0.0842 - val_accuracy: 0.9165
# Epoch 38/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9431 - val_loss: 0.0842 - val_accuracy: 0.9165
# Epoch 39/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9431 - val_loss: 0.0841 - val_accuracy: 0.9165
# Epoch 40/90
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0573 - accuracy: 0.9431 - val_loss: 0.0841 - val_accuracy: 0.9165
# Epoch 41/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0841 - val_accuracy: 0.9165
# Epoch 42/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0841 - val_accuracy: 0.9165
# Epoch 43/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0841 - val_accuracy: 0.9165
# Epoch 44/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0841 - val_accuracy: 0.9165
# Epoch 45/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9165
# Epoch 46/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9165
# Epoch 47/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9165
# Epoch 48/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9165
# Epoch 49/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9165
# Epoch 50/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0840 - val_accuracy: 0.9165
# Epoch 51/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 52/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 53/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 54/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 55/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 56/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 57/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 58/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 59/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 60/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 61/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 62/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0839 - val_accuracy: 0.9165
# Epoch 63/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 64/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 65/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 66/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 67/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 68/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 69/90
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 70/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 71/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 72/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 73/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 74/90
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 75/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 76/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 77/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 78/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 79/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 80/90
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 81/90
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 82/90
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 83/90
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0838 - val_accuracy: 0.9165
# Epoch 84/90
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
# Epoch 85/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
# Epoch 86/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
# Epoch 87/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
# Epoch 88/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
# Epoch 89/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
# Epoch 90/90
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9431 - val_loss: 0.0837 - val_accuracy: 0.9165
